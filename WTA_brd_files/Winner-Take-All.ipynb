# %%
import nengo
import numpy as np

dummy = 0
N = 16

n_neurons = 256
import nengo_brainstorm

model = nengo.Network()
nengo_brainstorm.add_params(model)

with model:
    stim = nengo.Node(lambda t: np.sin(t*np.pi*2))
    p_ideal = nengo.Probe(stim)
    
    def relu(x):
        return max(x, 0)
    
    for i in range(dummy):
        nengo.Ensemble(
                                     n_neurons=n_neurons,
                                     dimensions=1,
                                     intercepts=nengo.dists.Uniform(0,1),
                                     encoders=nengo.dists.Choice([[1]]),
                                     )
    
    
    a = nengo.networks.EnsembleArray(n_ensembles=N,
                                     n_neurons=n_neurons,
                                     intercepts=nengo.dists.Uniform(0,1),
                                     encoders=nengo.dists.Choice([[1]]),
                                     )
    for i in range(N):
        c = nengo.Node(lambda t,x: x, size_in=1, label='c%d'%i)
        nengo.Connection(stim, c)
        nengo.Connection(c, a.ea_ensembles[i])
        
    output_a = nengo.Node(lambda t, x: x, size_in=N)
    p_a = nengo.Probe(output_a)
    for i in range(N):
        c = nengo.Node(lambda t,x: x, size_in=1, label='c%d'%i)
        nengo.Connection(a.ea_ensembles[i], c, function=relu)
        nengo.Connection(c, output_a[i])
        
    '''
    b = nengo.networks.EnsembleArray(n_ensembles=N,
                                     n_neurons=n_neurons,
                                     intercepts=nengo.dists.Uniform(0,1),
                                     encoders=nengo.dists.Choice([[1]]),
                                     )
    for i in range(N):
        nengo.Connection(a.ea_ensembles[i], b.ea_ensembles[i])
    #nengo.Connection(a.output, b.input)
            
    output_b = nengo.Node(lambda t, x: x, size_in=N)
    for i in range(N):
        c = nengo.Node(lambda t,x: x, size_in=1, label='c%d'%i)
        nengo.Connection(b.ea_ensembles[i], c)
        nengo.Connection(c, output_b[i])
       '''

# %%
import nengo_brainstorm
sim = nengo_brainstorm.Simulator(model, precompute_inputs=True)
sim.run(1.0)
# Out:
# HAL: clearing hardware state
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for bias=-3
# Gathering spikes for <Ensemble "0"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# Gathering spikes for bias=-2
# Gathering spikes for <Ensemble "0"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# Gathering spikes for bias=-1
# Gathering spikes for <Ensemble "0"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# Gathering spikes for bias=0
# Gathering spikes for <Ensemble "0"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# Gathering spikes for bias=1
# Gathering spikes for <Ensemble "0"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 248-256
# ...
# Gathering spikes for <Ensemble "12"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# ... computing stats
# Gathering spikes for <Ensemble "0"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "0"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.05804341]
# Gathering spikes for <Ensemble "1"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "1"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.06760002]
# Gathering spikes for <Ensemble "2"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "2"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.05747442]
# Gathering spikes for <Ensemble "3"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "3"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.29887989]
# Gathering spikes for <Ensemble "4"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "4"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.05582849]
# Gathering spikes for <Ensemble "5"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "5"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.09420382]
# Gathering spikes for <Ensemble "6"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "6"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.05908247]
# Gathering spikes for <Ensemble "7"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "7"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.1261893]
# Gathering spikes for <Ensemble "8"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "8"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.2063963]
# Gathering spikes for <Ensemble "9"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "9"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.07305211]
# Gathering spikes for <Ensemble "10"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "10"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.26402664]
# Gathering spikes for <Ensemble "11"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "11"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.09330176]
# Gathering spikes for <Ensemble "12"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "12"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.08091645]
# Gathering spikes for <Ensemble "13"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "13"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.14405937]
# Gathering spikes for <Ensemble "14"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "14"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.07141646]
# Gathering spikes for <Ensemble "15"> neurons 0-124
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 124-248
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Gathering spikes for <Ensemble "15"> neurons 248-256
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# Computing pool stats
# ... computing stats
# decoder max(d) = 1  rmse=[0.08739883]
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# discarded 0 spikes and 0 outputs
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.

# %%
# %matplotlib inline
import pylab

# %%
pylab.figure(figsize=(14,14))
for i in range(N):
    pylab.subplot(4,4,i+1)
    pylab.plot(sim.trange(), np.array(sim.data[p_a])[:,i])
    pylab.plot(sim.trange(), np.maximum(np.array(sim.data[p_ideal]),0), ls='--')

# %%
sim.ens_cache[a.ea_ensembles[0]].cache_key()
# Out:
# '0,0 16x16 4a18764009c49be07522afe86250aa5aee858465'

# %%
import nengo
import numpy as np


good = [0,1,5]
N = len(good)

n_neurons = 256
import nengo_brainstorm

model = nengo.Network()
nengo_brainstorm.add_params(model)

def sine_wave(t, offset):
    return np.sin(t*np.pi*2+offset)
    

with model:
    stim = nengo.Node(lambda t: [sine_wave(t, offset=off) for off in np.linspace(0, 2*np.pi, N+1)[:N]])
    p_ideal = nengo.Probe(stim)
    
    def relu(x):
        return max(x, 0)
    def neg_relu(x):
        return -max(x, 0)
    +
    ensembles = []
    for i in range(16):
        ensembles.append(nengo.Ensemble(
                                     n_neurons=n_neurons,
                                     dimensions=1,
                                     intercepts=nengo.dists.Uniform(0,1),
                                     encoders=nengo.dists.Choice([[1]]),
                                     ))
    for i in range(N):
        c = nengo.Node(lambda t,x: x, size_in=1, label='c%d'%i)
        nengo.Connection(stim[i], c)
        nengo.Connection(c, ensembles[good[i]])
        
    output_a = nengo.Node(lambda t, x: x, size_in=N)
    p_a = nengo.Probe(output_a)
    for i in range(N):
        c = nengo.Node(lambda t,x: x, size_in=1, label='c%d'%i)
        nengo.Connection(ensembles[good[i]], c, function=relu)
        nengo.Connection(c, output_a[i])
        
    for i in range(N):
        for j in range(N):
            if i!=j:
                nengo.Connection(ensembles[good[i]], ensembles[good[j]], function=neg_relu)
        
    '''
    b = nengo.networks.EnsembleArray(n_ensembles=N,
                                     n_neurons=n_neurons,
                                     intercepts=nengo.dists.Uniform(0,1),
                                     encoders=nengo.dists.Choice([[1]]),
                                     )
    for i in range(N):
        nengo.Connection(a.ea_ensembles[i], b.ea_ensembles[i])
    #nengo.Connection(a.output, b.input)
            
    output_b = nengo.Node(lambda t, x: x, size_in=N)
    for i in range(N):
        c = nengo.Node(lambda t,x: x, size_in=1, label='c%d'%i)
        nengo.Connection(b.ea_ensembles[i], c)
        nengo.Connection(c, output_b[i])
       '''

# %%
import nengo_brainstorm
sim = nengo_brainstorm.Simulator(model, precompute_inputs=True)
sim.run(2.0)
# Out:
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# decoder max(d) = 1  rmse=[0.05804341 0.05804341]
# decoder max(d) = 1  rmse=[0.06760002 0.06760002]
# decoder max(d) = 1  rmse=[0.09420382 0.09420382]
# HAL: doing logical mapping
# mapping results written to mapped_core.txt
# HAL: programming mapping results to hardware
# HAL: clearing hardware state
# HAL: clearing queued-up outputs
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# discarded 0 spikes and 0 outputs
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.
# HtmlProgressBar cannot be displayed. Please use the TerminalProgressBar. It can be enabled with `nengo.rc.set('progress', 'progress_bar', 'nengo.utils.progress.TerminalProgressBar')`.

# %%
pylab.figure(figsize=(14,14))
for i in range(N):
    pylab.subplot(5,1,i+1)
    pylab.plot(sim.trange(), np.array(sim.data[p_a])[:,i])
    pylab.plot(sim.trange(), np.maximum(np.array(sim.data[p_ideal]),0), ls='--')

# %%
pylab.figure(figsize=(14,5))    
pylab.plot(sim.trange(), np.array(sim.data[p_a]))
pylab.gca().set_prop_cycle(None)
pylab.plot(sim.trange(), np.maximum(np.array(sim.data[p_ideal]),0), ls='--')
# Out:
# [<matplotlib.lines.Line2D at 0x7f8a80db2f98>,
#  <matplotlib.lines.Line2D at 0x7f8a80dbba20>,
#  <matplotlib.lines.Line2D at 0x7f8a80dbbb70>]
